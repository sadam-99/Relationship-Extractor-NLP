# %%
import numpy as np
import pandas as pd
import nltk
import spacy

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger') 
TokenNLP = spacy.load("en_core_web_sm")

import re
from nltk.stem import WordNetLemmatizer 
from spacy import displacy
from IPython.core.display import display, HTML
from nltk.corpus import wordnet as wn

nlp = spacy.load("en_core_web_sm")
class NLP_Part2:

  def __init__(self, path):
    self.path = path
    

  def clean_str(self, text):
    text = text.lower()
    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"that's", "that is ", text)
    text = re.sub(r"there's", "there is ", text)
    text = re.sub(r"it's", "it is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    return text.strip()

  def preprocess(self):
    sentenceList = []
    relationList = []
    lines = [line.strip() for line in open(self.path)]
    max_sentence_length = 0
    for idx in range(0, len(lines), 4):
      id = lines[idx].split("\t")[0]
      relation = lines[idx + 1]
      sentence = lines[idx].split("\t")[1][1:-1]
      sentence = sentence.replace('<e1>', ' _e11_ ')
      sentence = sentence.replace('</e1>', ' _e12_ ')
      sentence = sentence.replace('<e2>', ' _e21_ ')
      sentence = sentence.replace('</e2>', ' _e22_ ')
      sentence = self.clean_str(sentence)
      relationList.append(relation)
      sentenceList.append(sentence)
    return relationList, sentenceList

  
  def getRelationsOfSentences(self):
    relationMap = {}
    relationCount = 0
    relationList, sentenceList = self.preprocess()
    for sentence in sentenceList:
      e11Index = sentence.index('e11') + 3
      e12Index = sentence.index('e12')
      firstEntity = sentence[e11Index : e12Index]

      e21Index = sentence.index('e21') + 3
      e22Index = sentence.index('e22') 
      secondEntity = sentence[e21Index : e22Index]
      #print(firstEntity, " ", secondEntity, " ", relationList[relationCount])
      relationMap[relationCount] = [firstEntity, secondEntity, relationList[relationCount]]
      relationCount += 1
    print(" Entities and relation between them is -> ", relationMap)  
    return relationMap

  def tokenize(self, sentenceList):
    sentenceCount = 0
    tokenMap = {}
    for sentence in sentenceList:
      #print(sentenceCount, " ", sentence)
      sentence = sentence.replace('e11', '').replace('e12','').replace('e21','').replace('e22','')
      tokens = nltk.word_tokenize(sentence)
      tokenMap[sentenceCount] = tokens
      sentenceCount += 1
    print("Tokens of the sentence are -> " , tokenMap)
    return tokenMap

  def lemmatize(self, tokenMap):
    lemmatizer = WordNetLemmatizer() 
    lemmaMap = {}
    lemmaCount = 0
    for tokenList in tokenMap.values():
      lemmaList = []
      #print(" tokenList ", tokenList , "/n")
      for token in tokenList:
        lemmaList.append(lemmatizer.lemmatize(token))
      lemmaMap[lemmaCount] = lemmaList
      lemmaCount += 1
    print("Lemmas are -> ", lemmaMap)
    return lemmaMap

  def posTags(self, tokenMap):
    posMap = {}
    posCount = 0
    for tokenList in tokenMap.values():
      posTags= nltk.pos_tag(tokenList)
      #print("posTags ", posTags)
      posMap[posCount] = posTags
      posCount += 1
    print("Pos Tags are -> ", posMap)
    return posMap

  def getHyponymsAndHypernyms(self, tokenMap):
    print(" Hypernyms, Hyponyms, Meronyms are  ->   ")
    for sentence in sentenceList:
      sentence = sentence.replace('e11', " ").replace('e12'," ").replace('e21'," ").replace('e22'," ")
      tokendoc = TokenNLP(sentence)
      for token in tokendoc:
        print(" Token -> ", token)
        for ss in wn.synsets(token.lemma_):
          
          print ("hypernyms: "+str(ss.hypernyms())+" hyponyms: " + str(ss.hyponyms())+" holonyms: " + str(ss.member_holonyms())+" meronyms: "+ str(ss.part_meronyms()))
            
  def NERTags(self):
    NERMap = {}
    NERCount = 0
    for firstEntity, secondEntity, relationList in self.getRelationsOfSentences().values():
      docFirst = nlp(firstEntity)
      docSecond = nlp(secondEntity)
      NERList = []
      for ent in docFirst.ents:
        NERList.append((ent.text, ent.label_))
      for ent in docSecond.ents:
        NERList.append((ent.text, ent.label_))
      NERMap[NERCount] = NERList
      NERCount += 1
    
    print("NER Tags of the Entities are -> ", NERMap)
    return NERMap  

  def dependencyTree(self, sentenceList):
  
    dependecyMap = {}
    dependecyCount = 0
    for sentence in sentenceList:
      sentence = sentence.replace('e11', " ").replace('e12'," ").replace('e21'," ").replace('e22'," ")
      depedenlist = []
      tokendoc = TokenNLP(sentence)
      for token in tokendoc:
        depedenlist.append((token,token.dep_))
      dependecyMap[dependecyCount] = depedenlist
      dependecyCount += 1
      html = displacy.render(tokendoc, style="dep")
      # Uncomment below 2 lines
      print("Dependency Tree is ")
      display(HTML(html))
    print(" Dependency Tags are -> ", dependecyMap)

# Function calling Part
nlpPart2 = NLP_Part2("../DATA_FILES/Main_Data/Task2_TEST.TXT")
relationList, sentenceList = nlpPart2.preprocess()
tokenMap = nlpPart2.tokenize(sentenceList)
nlpPart2.lemmatize(tokenMap)
nlpPart2.posTags(tokenMap)
nlpPart2.getHyponymsAndHypernyms(sentenceList)
nlpPart2.NERTags()
nlpPart2.dependencyTree(sentenceList)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sadam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sadam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sadam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sadam\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Tokens of the sentence are ->  {0: ['the', 'final', 'decision', 'on', 'rank', 'which', 'will', 'be', 'made', 'by', 'navy', 'secretary', 'donald', 'c', 'winter', 'will', 'affect', 'stufflebeem', 'retirement', 'pay']}
# Lemmas are ->  {0: ['the', 'final', 'decision', 'on', 'rank', 'which', 'will', 'be', 'made', 'by', 'navy', 'secretary', 'donald', 'c', 'winter', 'will', 'affect', 'stufflebeem', 'retirement', 'pay']}
# Pos Tags are ->  {0: [('the', 'DT'), ('final', 'JJ'), ('decision', 'NN'), ('on', 'IN'), ('rank', 'NN'), ('which', 'WDT'), ('will', 'MD'), ('be', 'VB'), ('made', 'VBN'), ('by', 'IN'), ('navy', 'JJ'), ('secretary', 'NN'), ('donald', 'NN'), ('c', 'VBP'), ('winter', 'NN'), ('will', 'MD'), ('affect', 'VB'), ('stufflebeem', 'JJ'), ('retirement', 'NN'), ('pay', 'NN')]}
#  Hypernyms, Hyponyms, Meronyms are  ->
#  Token ->  the
#  Token ->  final
# hypernyms: [Synset('match.n.02')] hyponyms: [Synset('cup_final.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('examination.n.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  decision
# hypernyms: [Synset('choice.n.02')] hyponyms: [Synset('appointment.n.01'), Synset('call.n.12'), Synset('casting_lots.n.01'), Synset('move.n.01'), Synset('resolution.n.11')] holonyms: [] meronyms: []
# hypernyms: [Synset('judgment.n.01')] hyponyms: [Synset('predetermination.n.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('result.n.03')] hyponyms: [Synset('split_decision.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('result.n.03')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('resoluteness.n.01')] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  on
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  rank
# hypernyms: [Synset('line.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('status.n.01')] hyponyms: [Synset('archidiaconate.n.01'), Synset('baronetcy.n.01'), Synset('billionth.n.01'), Synset('dukedom.n.01'), Synset('earldom.n.01'), Synset('eighteenth.n.01'), Synset('eighth.n.01'), Synset('eightieth.n.01'), Synset('eleventh.n.01'), Synset('fifteenth.n.01'), Synset('fifth.n.02'), Synset('fiftieth.n.01'), Synset('first.n.01'), Synset('fortieth.n.01'), Synset('fourteenth.n.01'), Synset('fourth.n.01'), Synset('gradation.n.01'), Synset('grade.n.02'), Synset('hundredth.n.01'), Synset('kingship.n.01'), Synset('last.n.02'), Synset('military_rank.n.01'), Synset('millionth.n.01'), Synset('nineteenth.n.01'), Synset('ninetieth.n.01'), Synset('ninth.n.01'), Synset('princedom.n.01'), Synset('second.n.05'), Synset('second_class.n.01'), Synset('seventeenth.n.01'), Synset('seventh.n.01'), Synset('seventieth.n.01'), Synset('sixteenth.n.01'), Synset('sixth.n.01'), Synset('sixtieth.n.01'), Synset('tenth.n.02'), Synset('third.n.03'), Synset('thirteenth.n.01'), Synset('thirtieth.n.01'), Synset('thousandth.n.01'), Synset('twelfth.n.01'), Synset('twentieth.n.01'), Synset('viscountcy.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('force.n.04')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('status.n.01')] hyponyms: [Synset('place.n.10'), Synset('quality.n.05')] holonyms: [] meronyms: []
# hypernyms: [Synset('body.n.02')] hyponyms: [] holonyms: [Synset('organization.n.01')] meronyms: []
# hypernyms: [Synset('be.v.01')] hyponyms: [Synset('come.v.21'), Synset('place.v.06')] holonyms: [] meronyms: []
# hypernyms: [Synset('evaluate.v.02')] hyponyms: [Synset('downgrade.v.01'), Synset('prioritize.v.01'), Synset('reorder.v.01'), Synset('seed.v.05'), Synset('sequence.v.01'), Synset('shortlist.v.01'), Synset('subordinate.v.01'), Synset('superordinate.v.01'), Synset('upgrade.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('excel.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  which
#  Token ->  will
# hypernyms: [Synset('faculty.n.01')] hyponyms: [Synset('velleity.n.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('purpose.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('legal_document.n.01')] hyponyms: [Synset('devise.n.01'), Synset('new_testament.n.01'), Synset('old_testament.n.01')] holonyms: [] meronyms: [Synset('codicil.n.01')]
# hypernyms: [Synset('ordain.v.04')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('decide.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('give.v.08')] hyponyms: [Synset('devise.v.03'), Synset('fee-tail.v.01'), Synset('pass_on.v.04'), Synset('remember.v.04')] holonyms: [] meronyms: []
#  Token ->  be
# hypernyms: [Synset('metallic_element.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('abound.v.01'), Synset('accept.v.08'), Synset('account.v.01'), Synset('account_for.v.01'), Synset('act.v.06'), Synset('answer.v.06'), Synset('appear.v.04'), Synset('bake.v.04'), Synset('balance.v.04'), Synset('be_well.v.01'), Synset('beat.v.12'), Synset('begin.v.06'), Synset('begin.v.07'), Synset('belong.v.01'), Synset('belong.v.02'), Synset('belong.v.04'), Synset('belong.v.05'), Synset('breathe.v.04'), Synset('buy.v.03'), Synset('clean.v.05'), Synset('cohere.v.03'), Synset('come_in_for.v.01'), Synset('come_in_handy.v.01'), Synset('compact.v.01'), Synset('compare.v.02'), Synset('confuse.v.02'), Synset('connect.v.07'), Synset('consist.v.02'), Synset('consist.v.04'), Synset('contain.v.04'), Synset('contain.v.05'), Synset('continue.v.10'), Synset('cost.v.01'), Synset('count.v.02'), Synset('count.v.07'), Synset('cover.v.18'), Synset('cut.v.25'), Synset('cut_across.v.02'), Synset('deck.v.01'), Synset('depend.v.01'), Synset('deserve.v.01'), Synset('disagree.v.02'), Synset('distribute.v.09'), Synset('diverge.v.02'), Synset('draw.v.21'), Synset('end.v.03'), Synset('fall.v.04'), Synset('fall.v.16'), Synset('feel.v.04'), Synset('figure.v.02'), Synset('fit.v.07'), Synset('gape.v.02'), Synset('go.v.10'), Synset('gravitate.v.02'), Synset('hail.v.02'), Synset('hang.v.06'), Synset('head.v.04'), Synset('hold.v.17'), Synset('hoodoo.v.01'), Synset('hum.v.02'), Synset('impend.v.01'), Synset('incarnate.v.02'), Synset('iridesce.v.01'), Synset('jumble.v.01'), Synset('kill.v.04'), Synset('lend.v.03'), Synset('let_go.v.02'), Synset('lie.v.04'), Synset('litter.v.01'), Synset('loiter.v.01'), Synset('look.v.02'), Synset('look.v.03'), Synset('lubricate.v.01'), Synset('make.v.31'), Synset('make_sense.v.01'), Synset('measure.v.03'), Synset('mope.v.02'), Synset('object.v.02'), Synset('osculate.v.01'), Synset('owe.v.03'), Synset('pay.v.07'), Synset('point.v.10'), Synset('press.v.08'), Synset('promise.v.04'), Synset('prove.v.01'), Synset('put_out.v.06'), Synset('rage.v.02'), Synset('range.v.01'), Synset('rank.v.01'), Synset('rate.v.02'), Synset('recognize.v.08'), Synset('relate.v.04'), Synset('remain.v.03'), Synset('represent.v.03'), Synset('rest.v.01'), Synset('retard.v.02'), Synset('run.v.05'), Synset('run_into.v.01'), Synset('rut.v.01'), Synset('seem.v.03'), Synset('seethe.v.02'), Synset('sell.v.02'), Synset('sell.v.06'), Synset('sell.v.07'), Synset('shine.v.04'), Synset('shine.v.05'), Synset('sparkle.v.02'), Synset('specify.v.03'), Synset('squat.v.02'), Synset('stagnate.v.01'), Synset('stagnate.v.03'), Synset('stand.v.02'), Synset('stand.v.03'), Synset('stand_by.v.03'), Synset('stay.v.01'), Synset('stay.v.04'), Synset('stick.v.04'), Synset('stink.v.01'), Synset('subtend.v.01'), Synset('suck.v.04'), Synset('suffer.v.06'), Synset('suffer.v.08'), Synset('suit.v.02'), Synset('swim.v.03'), Synset('swim.v.04'), Synset('swing.v.10'), Synset('tend.v.01'), Synset('test.v.04'), Synset('total.v.01'), Synset('translate.v.07'), Synset('transplant.v.02'), Synset('trim.v.05'), Synset('underlie.v.01'), Synset('want.v.02'), Synset('wash.v.05'), Synset('wind.v.02'), Synset('work.v.14')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('attend.v.01'), Synset('belong.v.03'), Synset('center_on.v.02'), Synset('come.v.10'), Synset('cover.v.03'), Synset('extend.v.06'), Synset('face.v.04'), Synset('follow.v.08'), Synset('go.v.25'), Synset('inhabit.v.02'), Synset('lie.v.01'), Synset('lie.v.06'), Synset('occupy.v.03'), Synset('populate.v.01'), Synset('reach.v.06'), Synset('run.v.03'), Synset('sit.v.02'), Synset('sit.v.07'), Synset('stand_back.v.01'), Synset('straddle.v.01'), Synset('stretch.v.01')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('coexist.v.02'), Synset('come.v.06'), Synset('distribute.v.08'), Synset('dwell.v.02'), Synset('dwell.v.04'), Synset('endanger.v.01'), Synset('flow.v.04'), Synset('indwell.v.01'), Synset('kick_around.v.01'), Synset('preexist.v.01'), Synset('prevail.v.02')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('equate.v.02'), Synset('match.v.01'), Synset('represent.v.01'), Synset('translate.v.06')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('compose.v.01'), Synset('fall_into.v.01'), Synset('form.v.02'), Synset('make.v.34'), Synset('present.v.05'), Synset('range.v.04'), Synset('supplement.v.02')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('cox.v.01'), Synset('vet.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('typify.v.02')] hyponyms: [Synset('body.v.01'), Synset('exemplify.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('take.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('stay.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('be.v.01')] hyponyms: [Synset('set_back.v.03')] holonyms: [] meronyms: []
#  Token ->  made
# hypernyms: [Synset('kind.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('reordering.n.01')] hyponyms: [Synset('reshuffle.n.02'), Synset('riffle.n.02')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('overdo.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.01')] hyponyms: [Synset('get.v.03'), Synset('leave.v.03'), Synset('render.v.01')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('arouse.v.01'), Synset('assemble.v.01'), Synset('bear.v.05'), Synset('beat.v.18'), Synset('beget.v.01'), Synset('blast.v.05'), Synset('bring.v.03'), Synset('build.v.03'), Synset('cause.v.01'), Synset('chop.v.03'), Synset('choreograph.v.01'), Synset('clear.v.02'), Synset('cleave.v.02'), Synset('compose.v.02'), Synset('construct.v.01'), Synset('copy.v.04'), Synset('create.v.05'), Synset('create_by_mental_act.v.01'), Synset('create_from_raw_material.v.01'), Synset('create_verbally.v.01'), Synset('cut.v.06'), Synset('cut.v.22'), Synset('derive.v.04'), Synset('direct.v.03'), Synset('distill.v.03'), Synset('establish.v.05'), Synset('film-make.v.01'), Synset('film.v.02'), Synset('form.v.01'), Synset('froth.v.02'), Synset('generate.v.01'), Synset('give.v.09'), Synset('grind.v.06'), Synset('incorporate.v.03'), Synset('institute.v.02'), Synset('lay_down.v.01'), Synset('manufacture.v.04'), Synset('offset.v.04'), Synset('originate.v.02'), Synset('prepare.v.03'), Synset('press.v.07'), Synset('produce.v.01'), Synset('produce.v.03'), Synset('puncture.v.02'), Synset('put_on.v.04'), Synset('raise.v.07'), Synset('raise.v.11'), Synset('re-create.v.01'), Synset('realize.v.03'), Synset('recreate.v.04'), Synset('regenerate.v.07'), Synset('reproduce.v.02'), Synset('scrape.v.02'), Synset('short-circuit.v.02'), Synset('strike.v.13'), Synset('style.v.02'), Synset('track.v.05'), Synset('twine.v.03')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('bring.v.11'), Synset('compel.v.01'), Synset('decide.v.03'), Synset('encourage.v.03'), Synset('lead.v.05'), Synset('let.v.02'), Synset('persuade.v.02'), Synset('prompt.v.02'), Synset('solicit.v.04'), Synset('suborn.v.03')] holonyms: [] meronyms: []
# hypernyms: [Synset('make.v.03')] hyponyms: [Synset('determine.v.02'), Synset('effect.v.01'), Synset('engender.v.01'), Synset('facilitate.v.03'), Synset('impel.v.01'), Synset('initiate.v.02'), Synset('make.v.08'), Synset('motivate.v.01'), Synset('occasion.v.01'), Synset('provoke.v.02')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('bootleg.v.02'), Synset('breed.v.03'), Synset('churn_out.v.02'), Synset('clap_up.v.01'), Synset('confect.v.01'), Synset('custom-make.v.01'), Synset('cut.v.21'), Synset('dummy.v.01'), Synset('elaborate.v.02'), Synset('extrude.v.01'), Synset('fudge_together.v.01'), Synset('generate.v.03'), Synset('laminate.v.01'), Synset('machine.v.02'), Synset('output.v.01'), Synset('overproduce.v.02'), Synset('prefabricate.v.01'), Synset('prefabricate.v.02'), Synset('print.v.01'), Synset('proof.v.01'), Synset('pulse.v.02'), Synset('put_out.v.02'), Synset('remake.v.01'), Synset('render.v.04'), Synset('reproduce.v.01'), Synset('smelt.v.01'), Synset('turn_out.v.03'), Synset('underproduce.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('create_by_mental_act.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('cause.v.01')] hyponyms: [Synset('drive.v.07')] holonyms: [] meronyms: []
# hypernyms: [Synset('make.v.03')] hyponyms: [Synset('design.v.03'), Synset('design.v.05'), Synset('do.v.08')] holonyms: [] meronyms: []
# hypernyms: [Synset('get.v.01')] hyponyms: [Synset('eke_out.v.03'), Synset('gross.v.01'), Synset('profit.v.02'), Synset('rake_in.v.01'), Synset('rake_off.v.01'), Synset('take_home.v.01'), Synset('yield.v.10')] holonyms: [] meronyms: []
# hypernyms: [Synset('create.v.05')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('constitute.v.01')] hyponyms: [Synset('add.v.06'), Synset('chelate.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('achieve.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('become.v.03')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('create_from_raw_material.v.01')] hyponyms: [Synset('compile.v.03'), Synset('compose.v.04'), Synset('cooper.v.01'), Synset('fashion.v.01'), Synset('manufacture.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('perform.v.01')] hyponyms: [Synset('pay.v.08')] holonyms: [] meronyms: []
# hypernyms: [Synset('make.v.03')] hyponyms: [Synset('cantilever.v.02'), Synset('channelize.v.02'), Synset('corduroy.v.01'), Synset('customize.v.02'), Synset('dry-wall.v.01'), Synset('frame.v.06'), Synset('groin.v.01'), Synset('lock.v.09'), Synset('raise.v.09'), Synset('rebuild.v.01'), Synset('revet.v.01'), Synset('wattle.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('act.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('appoint.v.02')] hyponyms: [Synset('rename.v.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('score.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('access.v.02'), Synset('bottom_out.v.01'), Synset('catch_up.v.01'), Synset('culminate.v.04'), Synset('find.v.15'), Synset('get_through.v.03'), Synset('ground.v.06'), Synset('make.v.37'), Synset('scale.v.04'), Synset('summit.v.01'), Synset('top.v.06'), Synset('top_out.v.03')] holonyms: [] meronyms: []
# hypernyms: [Synset('make.v.03')] hyponyms: [Synset('set.v.04')] holonyms: [] meronyms: []
# hypernyms: [Synset('perpetrate.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('assemble.v.03')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('direct.v.04')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('tidy.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('head.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('excrete.v.01')] hyponyms: [Synset('dung.v.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('be.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('total.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('amount.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('constitute.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('look.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('pass.v.01')] hyponyms: [Synset('bushwhack.v.03'), Synset('claw.v.01'), Synset('jostle.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('reach.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('create_from_raw_material.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('create_from_raw_material.v.01')] hyponyms: [Synset('concoct.v.02'), Synset('deglaze.v.01'), Synset('devil.v.02'), Synset('dress.v.06'), Synset('flambe.v.01'), Synset('lard.v.01'), Synset('precook.v.01'), Synset('preserve.v.04'), Synset('put_on.v.03'), Synset('scallop.v.02'), Synset('whip_up.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('persuade.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('guarantee.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('act.v.03')] hyponyms: [Synset('go_through_the_motions.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('see.v.05')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('estimate.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('develop.v.13')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('develop.v.14')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('act.v.02')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('excrete.v.01')] hyponyms: [Synset('stale.v.01'), Synset('wet.v.02')] holonyms: [] meronyms: []
#  Token ->  by
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
#  Token ->
#  Token ->  navy
# hypernyms: [Synset('military_service.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('blue.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('agency.n.01')] hyponyms: [] holonyms: [] meronyms: [Synset('naval_air_warfare_center_weapons_division.n.01'), Synset('naval_research_laboratory.n.01'), Synset('naval_special_warfare.n.01'), Synset('naval_surface_warfare_center.n.01'), Synset('naval_underwater_warfare_center.n.01'), Synset('office_of_naval_intelligence.n.01'), Synset('united_states_marine_corps.n.01'), Synset('united_states_naval_academy.n.01')]
#  Token ->
#  Token ->  secretary
# hypernyms: [Synset('head.n.04')] hyponyms: [Synset('attorney_general.n.02'), Synset('secretary_of_agriculture.n.01'), Synset('secretary_of_commerce.n.01'), Synset('secretary_of_defense.n.01'), Synset('secretary_of_education.n.01'), Synset('secretary_of_energy.n.01'), Synset('secretary_of_health_and_human_services.n.01'), Synset('secretary_of_housing_and_urban_development.n.01'), Synset('secretary_of_labor.n.01'), Synset('secretary_of_state.n.01'), Synset('secretary_of_the_interior.n.02'), Synset('secretary_of_the_treasury.n.01'), Synset('secretary_of_transportation.n.01'), Synset('secretary_of_veterans_affairs.n.01'), Synset('undersecretary.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('assistant.n.01')] hyponyms: [Synset('executive_secretary.n.01'), Synset('receptionist.n.01'), Synset('social_secretary.n.01'), Synset('stenographer.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('confidant.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('desk.n.01')] hyponyms: [] holonyms: [] meronyms: []
#  Token ->
#  Token ->  donald
#  Token ->  c
# hypernyms: [Synset('degree.n.06')] hyponyms: [Synset('standard_temperature.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('constant.n.02'), Synset('speed.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('antioxidant.n.01'), Synset('water-soluble_vitamin.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('nucleotide.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('pyrimidine.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('chemical_element.n.01')] hyponyms: [Synset('activated_carbon.n.01'), Synset('carbon_black.n.01'), Synset('char.n.01'), Synset('charcoal.n.01'), Synset('diamond.n.02'), Synset('fullerene.n.01'), Synset('graphite.n.01'), Synset('radiocarbon.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('large_integer.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('charge_unit.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('programming_language.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('tonic.n.03')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('letter.n.02')] hyponyms: [] holonyms: [Synset('roman_alphabet.n.01')] meronyms: []
# hypernyms: [Synset('cocaine.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  winter
# hypernyms: [Synset('season.n.02')] hyponyms: [] holonyms: [] meronyms: [Synset('midwinter.n.01'), Synset('winter_solstice.n.01')]
# hypernyms: [Synset('spend.v.01')] hyponyms: [] holonyms: [] meronyms: []
#  Token ->
#  Token ->  will
# hypernyms: [Synset('faculty.n.01')] hyponyms: [Synset('velleity.n.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('purpose.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('legal_document.n.01')] hyponyms: [Synset('devise.n.01'), Synset('new_testament.n.01'), Synset('old_testament.n.01')] holonyms: [] meronyms: [Synset('codicil.n.01')]
# hypernyms: [Synset('ordain.v.04')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('decide.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('give.v.08')] hyponyms: [Synset('devise.v.03'), Synset('fee-tail.v.01'), Synset('pass_on.v.04'), Synset('remember.v.04')] holonyms: [] meronyms: []
#  Token ->  affect
# hypernyms: [Synset('feeling.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.01')] hyponyms: [Synset('hit.v.05'), Synset('hydrolize.v.01'), Synset('influence.v.01'), Synset('process.v.01'), Synset('queer.v.02'), Synset('redound.v.03'), Synset('repercuss.v.01'), Synset('slam-dunk.v.01'), Synset('stimulate.v.01'), Synset('strike_a_blow.v.01'), Synset('subject.v.01'), Synset('tell_on.v.02'), Synset('tinge.v.01'), Synset('trouble.v.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('change.v.01')] hyponyms: [Synset('attack.v.06'), Synset('cramp.v.03'), Synset('intoxicate.v.02'), Synset('jaundice.v.02'), Synset('register.v.10'), Synset('relax.v.04'), Synset('sedate.v.01'), Synset('stimulate.v.04'), Synset('tense.v.04'), Synset('ulcerate.v.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('refer.v.02')] hyponyms: [Synset('implicate.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('misrepresent.v.01')] hyponyms: [Synset('mouth.v.02'), Synset('play_possum.v.01'), Synset('take_a_dive.v.01'), Synset('talk_through_one's_hat.v.01')] holonyms: [] meronyms: []
# hypernyms: [] hyponyms: [Synset('alienate.v.03'), Synset('awaken.v.03'), Synset('cloud.v.04'), Synset('disturb.v.01'), Synset('engrave.v.02'), Synset('hit_home.v.01'), Synset('impress.v.02'), Synset('impress.v.03'), Synset('infect.v.04'), Synset('jar.v.04'), Synset('move.v.11'), Synset('pierce.v.02'), Synset('sadden.v.01'), Synset('smite.v.02'), Synset('strike_dumb.v.01'), Synset('surprise.v.01'), Synset('sweep_away.v.02'), Synset('touch.v.03'), Synset('zap.v.01')] holonyms: [] meronyms: []
#  Token ->  stufflebeem
#  Token ->  retirement
# hypernyms: [Synset('status.n.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('termination.n.05')] hyponyms: [Synset('hibernation.n.03'), Synset('rustication.n.03')] holonyms: [] meronyms: []
# hypernyms: [Synset('withdrawal.n.03')] hyponyms: [] holonyms: [] meronyms: []
#  Token ->  pay
# hypernyms: [Synset('regular_payment.n.01')] hyponyms: [Synset('combat_pay.n.01'), Synset('double_time.n.02'), Synset('found.n.01'), Synset('half-pay.n.01'), Synset('living_wage.n.01'), Synset('merit_pay.n.01'), Synset('minimum_wage.n.01'), Synset('pay_envelope.n.01'), Synset('sick_pay.n.01'), Synset('strike_pay.n.01'), Synset('take-home_pay.n.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('give.v.03')] hyponyms: [Synset('bribe.v.01'), Synset('charge.v.12'), Synset('compensate.v.02'), Synset('compensate.v.06'), Synset('defray.v.01'), Synset('disburse.v.01'), Synset('finance.v.01'), Synset('foot.v.01'), Synset('go_dutch.v.01'), Synset('kick_back.v.01'), Synset('overpay.v.01'), Synset('pay_cash.v.01'), Synset('prefer.v.04'), Synset('prepay.v.01'), Synset('put_up.v.08'), Synset('redeem.v.05'), Synset('refund.v.01'), Synset('remit.v.01'), Synset('spend.v.02'), Synset('subsidize.v.02'), Synset('tithe.v.04'), Synset('underpay.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('communicate.v.02')] hyponyms: [Synset('offer.v.05')] holonyms: [] meronyms: []
# hypernyms: [Synset('pay.v.11')] hyponyms: [Synset('liquidate.v.02')] holonyms: [] meronyms: []
# hypernyms: [Synset('gain.v.08')] hyponyms: [Synset('net.v.02'), Synset('pay_off.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('settle.v.14')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('think.v.03')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('be.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('make.v.16')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('digest.v.03')] hyponyms: [Synset('take_one's_lumps.v.01')] holonyms: [] meronyms: []
# hypernyms: [Synset('requite.v.01')] hyponyms: [] holonyms: [] meronyms: []
# hypernyms: [Synset('settle.v.14')] hyponyms: [Synset('pay_up.v.01')] holonyms: [] meronyms: []
#  Entities and relation between them is ->  {0: [' navy ', ' donald c winter ', 'Member-Collection(e2,e1)']}
# NER Tags of the Entities are ->  {0: [('navy', 'ORG'), ('donald', 'PERSON')]}
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7b7fa0807bf344d1a9891efade404edd-0" class="displacy" width="4250" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">final</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">decision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">rank</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">navy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">secretary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">c</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">winter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">affect</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">stufflebeem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">retirement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">pay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7b7fa0807bf344d1a9891efade404edd-0-0" stroke-width="2px" d="M70,527.0 C70,352.0 380.0,352.0 380.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7b7fa0807bf344d1a9891efade404edd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7b7fa0807bf344d1a9891efade404edd-0-1" stroke-width="2px" d="M245,527.0 C245,439.5 375.0,439.5 375.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7b7fa0807bf344d1a9891efade404edd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7b7fa0807bf344d1a9891efade404edd-0-2" stroke-width="2px" d="M420,527.0 C420,2.0 3550.0,2.0 3550.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7b7fa0807bf344d1a9891efade404edd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,529.0 L412,517.0 428,517.0" fill="cu
# Dependency Tree is
#  Dependency Tags are ->  {0: [(the, 'det'), (final, 'amod'), (decision, 'nsubj'), (on, 'prep'), (rank, 'pobj'), (which, 'nsubjpass'), (will, 'aux'), (be, 'auxpass'), (made, 'relcl'), (by, 'agent'), (  , ''), (navy, 'nmod'), (  , ''), (secretary, 'pobj'), (  , ''), (donald, 'compound'), (c, 'compound'), (winter, 'appos'), (  , ''), (will, 'aux'), (affect, 'ROOT'), (stufflebeem, 'compound'), (retirement, 'compound'), (pay, 'dobj')]}
